# %%
import pandas as pd
df = pd.read_csv('yelp_labelled.txt', names=['sentence', 'label'], sep='\t')

# %%
df.tail()
# Out:
#                                               sentence  label
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0

# %%
from sklearn.model_selection import train_test_split
kalimat = df['sentence'].values
y = df['label'].values
kalimat_latih, kalimat_test, y_latih, y_test = train_test_split(kalimat, y, test_size=0.2)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words=250, oov_token='x')
tokenizer.fit_on_texts(kalimat_latih)
tokenizer.fit_on_texts(kalimat_test)

sekuens_latih = tokenizer.texts_to_sequences(kalimat_latih)
sekuens_test = tokenizer.texts_to_sequences(kalimat_test)

padded_latih = pad_sequences(sekuens_latih, maxlen=20) #pad_sequences: make sequences same in length
padded_test = pad_sequences(sekuens_test, maxlen=20)

# %%
import tensorflow as tf
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(250, 16, input_length=20),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
num_epochs = 30
history = model.fit(padded_latih, y_latih, epochs=num_epochs,
                    validation_data=(padded_test, y_test), verbose=2)
# Out:
# Epoch 1/30
# 25/25 - 1s - loss: 0.6928 - accuracy: 0.5050 - val_loss: 0.6908 - val_accuracy: 0.5850 - 1s/epoch - 46ms/step
# Epoch 2/30
# 25/25 - 0s - loss: 0.6902 - accuracy: 0.6338 - val_loss: 0.6876 - val_accuracy: 0.7450 - 82ms/epoch - 3ms/step
# Epoch 3/30
# 25/25 - 0s - loss: 0.6864 - accuracy: 0.6338 - val_loss: 0.6828 - val_accuracy: 0.6500 - 89ms/epoch - 4ms/step
# Epoch 4/30
# 25/25 - 0s - loss: 0.6801 - accuracy: 0.6862 - val_loss: 0.6751 - val_accuracy: 0.6900 - 79ms/epoch - 3ms/step
# Epoch 5/30
# 25/25 - 0s - loss: 0.6704 - accuracy: 0.7013 - val_loss: 0.6630 - val_accuracy: 0.6800 - 78ms/epoch - 3ms/step
# Epoch 6/30
# 25/25 - 0s - loss: 0.6561 - accuracy: 0.7350 - val_loss: 0.6481 - val_accuracy: 0.7350 - 79ms/epoch - 3ms/step
# Epoch 7/30
# 25/25 - 0s - loss: 0.6359 - accuracy: 0.7563 - val_loss: 0.6287 - val_accuracy: 0.7400 - 85ms/epoch - 3ms/step
# Epoch 8/30
# 25/25 - 0s - loss: 0.6129 - accuracy: 0.7538 - val_loss: 0.6069 - val_accuracy: 0.7650 - 86ms/epoch - 3ms/step
# Epoch 9/30
# 25/25 - 0s - loss: 0.5841 - accuracy: 0.7738 - val_loss: 0.5867 - val_accuracy: 0.7600 - 93ms/epoch - 4ms/step
# Epoch 10/30
# 25/25 - 0s - loss: 0.5519 - accuracy: 0.8062 - val_loss: 0.5627 - val_accuracy: 0.7750 - 82ms/epoch - 3ms/step
# Epoch 11/30
# 25/25 - 0s - loss: 0.5197 - accuracy: 0.8213 - val_loss: 0.5424 - val_accuracy: 0.7900 - 78ms/epoch - 3ms/step
# Epoch 12/30
# 25/25 - 0s - loss: 0.4903 - accuracy: 0.8250 - val_loss: 0.5217 - val_accuracy: 0.8000 - 85ms/epoch - 3ms/step
# Epoch 13/30
# 25/25 - 0s - loss: 0.4606 - accuracy: 0.8425 - val_loss: 0.5061 - val_accuracy: 0.7900 - 100ms/epoch - 4ms/step
# Epoch 14/30
# 25/25 - 0s - loss: 0.4354 - accuracy: 0.8388 - val_loss: 0.4911 - val_accuracy: 0.8100 - 86ms/epoch - 3ms/step
# Epoch 15/30
# 25/25 - 0s - loss: 0.4130 - accuracy: 0.8562 - val_loss: 0.4816 - val_accuracy: 0.7900 - 100ms/epoch - 4ms/step
# Epoch 16/30
# 25/25 - 0s - loss: 0.3923 - accuracy: 0.8550 - val_loss: 0.4733 - val_accuracy: 0.7950 - 86ms/epoch - 3ms/step
# Epoch 17/30
# 25/25 - 0s - loss: 0.3752 - accuracy: 0.8687 - val_loss: 0.4687 - val_accuracy: 0.7850 - 92ms/epoch - 4ms/step
# Epoch 18/30
# 25/25 - 0s - loss: 0.3602 - accuracy: 0.8575 - val_loss: 0.4646 - val_accuracy: 0.7900 - 96ms/epoch - 4ms/step
# Epoch 19/30
# 25/25 - 0s - loss: 0.3479 - accuracy: 0.8700 - val_loss: 0.4615 - val_accuracy: 0.8000 - 85ms/epoch - 3ms/step
# Epoch 20/30
# 25/25 - 0s - loss: 0.3375 - accuracy: 0.8612 - val_loss: 0.4689 - val_accuracy: 0.7700 - 101ms/epoch - 4ms/step
# Epoch 21/30
# 25/25 - 0s - loss: 0.3261 - accuracy: 0.8863 - val_loss: 0.4623 - val_accuracy: 0.7850 - 97ms/epoch - 4ms/step
# Epoch 22/30
# 25/25 - 0s - loss: 0.3170 - accuracy: 0.8700 - val_loss: 0.4653 - val_accuracy: 0.7900 - 86ms/epoch - 3ms/step
# Epoch 23/30
# 25/25 - 0s - loss: 0.3102 - accuracy: 0.8825 - val_loss: 0.4699 - val_accuracy: 0.7700 - 86ms/epoch - 3ms/step
# Epoch 24/30
# 25/25 - 0s - loss: 0.3020 - accuracy: 0.8825 - val_loss: 0.4802 - val_accuracy: 0.7700 - 85ms/epoch - 3ms/step
# Epoch 25/30
# 25/25 - 0s - loss: 0.2971 - accuracy: 0.8825 - val_loss: 0.4771 - val_accuracy: 0.7650 - 87ms/epoch - 3ms/step
# Epoch 26/30
# 25/25 - 0s - loss: 0.2903 - accuracy: 0.8838 - val_loss: 0.4812 - val_accuracy: 0.7750 - 97ms/epoch - 4ms/step
# Epoch 27/30
# 25/25 - 0s - loss: 0.2876 - accuracy: 0.8863 - val_loss: 0.5004 - val_accuracy: 0.7900 - 97ms/epoch - 4ms/step
# Epoch 28/30
# 25/25 - 0s - loss: 0.2879 - accuracy: 0.8900 - val_loss: 0.4946 - val_accuracy: 0.7700 - 94ms/epoch - 4ms/step
# Epoch 29/30
# 25/25 - 0s - loss: 0.2838 - accuracy: 0.8813 - val_loss: 0.5060 - val_accuracy: 0.7800 - 83ms/epoch - 3ms/step
# Epoch 30/30
# 25/25 - 0s - loss: 0.2738 - accuracy: 0.8950 - val_loss: 0.5053 - val_accuracy: 0.7700 - 93ms/epoch - 4ms/step
